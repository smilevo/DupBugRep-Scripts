# %%
import bson, sys
import pandas as pd
f = sys.argv[1]
with open('initial.bson','rb') as f:
    data = bson.decode_all(f.read()) # list of dicts : each row is a dict

fn = fn.replace("bson", "csv")
df = pd.DataFrame(data)
df.to_csv(fn)
# Out:
# ---------------------------------------------------------------------------
# InvalidBSON                               Traceback (most recent call last)
# <ipython-input-23-60f2a566faed> in <module>()
#       3 f = sys.argv[1]
#       4 with open('initial.bson','rb') as f:
# ----> 5     data = bson.decode_all(f.read()) # list of dicts : each row is a dict
#       6
#       7 fn = fn.replace("bson", "csv")
#
# InvalidBSON: objsize too large

# %%
import bson
with open('initial.bson','rb') as f:
    data = bson.decode_all(f.read())
# Out:
# ---------------------------------------------------------------------------
# InvalidBSON                               Traceback (most recent call last)
# <ipython-input-21-10ea0c1ff07b> in <module>()
#       1 import bson
#       2 with open('initial.bson','rb') as f:
# ----> 3     data = bson.decode_all(f.read())
#
# InvalidBSON: objsize too large

# %%
data
# Out:
# [{'_id': ObjectId('5307f2f3166663d2e3fd8b6f'),
#   'bug1': 200622,
#   'bug2': 197347,
#   'dec': 1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b70'),
#   'bug1': 186130,
#   'bug2': 187255,
#   'dec': 1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b71'),
#   'bug1': 8715,
#   'bug2': 195514,
#   'dec': -1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b72'),
#   'bug1': 47174,
#   'bug2': 95177,
#   'dec': -1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b73'),
#   'bug1': 89581,
#   'bug2': 223725,
#   'dec': -1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b74'),
#   'bug1': 219751,
#   'bug2': 186408,
#   'dec': -1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b75'),
#   'bug1': 193020,
#   'bug2': 191173,
#   'dec': 1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b76'),
#   'bug1': 64509,
#   'bug2': 67769,
#   'dec': 1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b77'),
#   'bug1': 203815,
#   'bug2': 209842,
#   'dec': 1},
#  {'_id': ObjectId('5307f2f3166663d2e3fd8b78'),
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import bson
import io
#from skimage.data import imread

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
data = bson.decode_file_iter(open('f.bson', 'rb'))

df=pd.DataFrame({"category":[]})
df=pd.concat([df,pd.DataFrame(columns=[i for i in range(180*180*3)])])
df['category'].astype('object')
index=0
pd.options.display.precision=11
'''
for i,j in enumerate(data):
    for k in range(len(j['imgs'])):
        image=np.reshape((imread(io.BytesIO(j['imgs'][k]['picture']))),-1)
        image=image.tolist()
        image.insert(0,j["category_id"])
        df.loc[index]=image
        index=index+1    
       '''     
        
df.to_csv("test.csv",index=False)

# %%
import numpy as np
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split
import warnings
import re
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('Dup_part1 _TBird.csv',delimiter=';')
df2=pd.read_csv('Total_thunderBird.csv',delimiter=';')
for (i, rowg) in df1.iterrows():
  for (j, rowf) in df2.iterrows():
        if (rowg['Duplicated_issue']== rowf['Issue_id']):             
          df1.loc[df1.index[i], 'Description2'] = rowf['Description']
          df1.loc[df1.index[i], 'Title2'] = rowf['Title']
        if (rowg['Issue_id']== rowf['Issue_id']):
          df1.loc[df1.index[i], 'Title1'] = rowf['Title']
          df1.loc[df1.index[i], 'Description1'] = rowf['Description']
         #print(rowg['Issue_id'],rowg['Description'],rowf['Issue_id'],rowf['Description'])
          df1.to_csv('vide_dup_TB.csv')
print(df1)
# Out:
#       Issue_id  ...                                             Title2
# 0       209996  ...  sent mail box screen shakes up and down  even ...
# 1       214111  ...                 group actions on collapsed threads
# 2       214126  ...  can not invoke mozilla firebird to do web surf...
# 3       214354  ...  crash with message gdkwarning  gdkdrawablexc d...
# 4       214358  ...  double clicking scrollbar updown arrows in con...
# ...        ...  ...                                                ...
# 4353    942785  ...   how am i supose to move the window on my screen
# 4354    944833  ...  placessqlite created when i click on a link in...
# 4355    947068  ...  switch from the toolkit loadingpng to our own ...
# 4356    950576  ...  mail display truncates url when containing  sq...
# 4357    952829  ...        no support for xmpp self signed certificate
#
# [4358 rows x 8 columns]

# %%
df1=pd.read_csv('dup_part14.csv',delimiter=';')
df2=pd.read_csv('Final_Dataset.csv',delimiter=';')
for (i, rowg) in df1.iterrows():
  for (j, rowf) in df2.iterrows():
        if (rowg['Duplicated_issue']== rowf['Issue_id']):             
          df1.loc[df1.index[i], 'Description2'] = rowf['Description']
          df1.loc[df1.index[i], 'Title2'] = rowf['Title']
        if (rowg['Issue_id']== rowf['Issue_id']):
          df1.loc[df1.index[i], 'Title1'] = rowf['Title']
          df1.loc[df1.index[i], 'Description1'] = rowf['Description']
          #print(rowg['Issue_id'],rowg['Description'],rowf['Issue_id'],rowf['Description'])
          df1.to_csv('vide14.csv')

print(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Issue_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-d220d9732abf> in <module>()
# ...

# %%
df1=pd.read_csv('vide10.csv',delimiter=';')

# %%
df['Label']=df
